# %% [markdown]
# # **3.1**
# 本文提出一种结合传统趋势策略与深度学习风控能力的深度混合决策框架，由基准策略层与LSTM决策层构成。系统的核心表现为双层协作机制：基准层利用加权移动平均（WMA）交叉信号捕捉趋势并触发入场；持仓期间，LSTM层作为智能风控插件，实时预测执行“提前平仓”的条件概率。一旦该概率超越预设阈值，系统将在传统信号反转前强制平仓，以锁定利润或规避大幅回撤。该架构通过在传统规则之上叠加数据驱动决策层，显著提升了精细化持仓管理能力。
